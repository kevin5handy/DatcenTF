# %% [markdown]
# # Important Library

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random
import joblib
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %% [markdown]
# # Load the Datasets

# %%
# Load the dataset

df = pd.read_csv('/content/drive/My Drive/Project 2 (TPT)/time_clean.csv')
df.head()
# Out:
#    Unnamed: 0                 time  moduleInletTemp__ch1  \
# 0           1  2024-07-16 10:41:10                  15.1
# 1           2  2024-07-16 10:41:20                  15.1
# 2           3  2024-07-16 10:41:30                  15.1
# 3           4  2024-07-16 10:41:40                  15.2
# 4           5  2024-07-16 10:41:50                  15.2
#
#    moduleOutletTemp__ch1  totalInletWater__ch1  totalOutletWater__ch1  \
# 0                   15.2                  15.1                   15.2
# 1                   15.2                  15.1                   15.2
# 2                   15.2                  15.1                   15.2
# 3                   15.3                  15.2                   15.3
# 4                   15.3                  15.2                   15.3
#
#    moduleInletTemp__ch2  moduleOutletTemp__ch2  totalInletWater__ch2  \
# 0                  14.9                   15.1                  14.9
# 1                  14.9                   15.1                  14.9
# 2                  14.9                   15.1                  14.9
# 3                  14.9                   15.1                  14.9
# 4                  15.0                   15.1                  15.0
#
#    totalOutletWater__ch2  ...  water_in_temp__ir1  water_out_temp__ir1  \
# 0                   15.1  ...              15.070               14.960
# 1                   15.1  ...              15.070               15.015
# 2                   15.1  ...              15.070               14.960
# 3                   15.1  ...              15.070               15.015
# 4                   15.1  ...              15.015               15.015
#
#    supp_temp__ir2  return_temp__ir2  fan_speed__ir2  unt_airflow__ir2  \
# 0          20.075            21.835           247.3              62.0
# 1          20.020            21.835           247.2              62.0
# 2          19.965            21.780           247.2              62.0
# 3          19.965            21.780           223.8              56.0
# 4          19.910            21.835           231.1              58.0
#
#    water_flow__ir2  water_in_temp__ir2  water_out_temp__ir2   power
# 0             10.5              15.455               20.515  244.86
# 1             10.3              15.510               20.515  245.08
# 2             10.3              15.455               20.460  245.30
# 3             10.5              15.455               20.350  200.70
# 4             10.3              15.565               20.350  223.10
#
# [5 rows x 25 columns]

# %% [markdown]
# # Data Wrangling

# %%
# dataset info

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 338151 entries, 0 to 338150
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             338151 non-null  int64
#  1   time                   338151 non-null  object
#  2   moduleInletTemp__ch1   338151 non-null  float64
#  3   moduleOutletTemp__ch1  338151 non-null  float64
#  4   totalInletWater__ch1   338151 non-null  float64
#  5   totalOutletWater__ch1  338151 non-null  float64
#  6   moduleInletTemp__ch2   338151 non-null  float64
#  7   moduleOutletTemp__ch2  338151 non-null  float64
#  8   totalInletWater__ch2   338151 non-null  float64
#  9   totalOutletWater__ch2  338151 non-null  float64
#  10  supp_temp__ir1         338151 non-null  float64
#  11  return_temp__ir1       338151 non-null  float64
#  12  fan_speed__ir1         338151 non-null  float64
#  13  unt_airflow__ir1       338151 non-null  float64
#  14  water_flow__ir1        338151 non-null  float64
#  15  water_in_temp__ir1     338151 non-null  float64
#  16  water_out_temp__ir1    338151 non-null  float64
#  17  supp_temp__ir2         338151 non-null  float64
#  18  return_temp__ir2       338151 non-null  float64
#  19  fan_speed__ir2         338151 non-null  float64
#  20  unt_airflow__ir2       338151 non-null  float64
#  21  water_flow__ir2        338151 non-null  float64
#  22  water_in_temp__ir2     338151 non-null  float64
#  23  water_out_temp__ir2    338151 non-null  float64
#  24  power                  338151 non-null  float64
# dtypes: float64(23), int64(1), object(1)
# memory usage: 64.5+ MB

# %%
# statistical info

df.describe()
# Out:
#           Unnamed: 0  moduleInletTemp__ch1  moduleOutletTemp__ch1  \
# count  338151.000000         338151.000000          338151.000000
# mean   169133.772942             16.202258              15.598329
# std     97616.321580              1.209454               1.520875
# min         1.000000             13.100000              11.300000
# 25%     84596.500000             15.300000              14.700000
# 50%    169134.000000             16.200000              15.900000
# 75%    253671.500000             17.200000              16.700000
# max    338209.000000             19.400000              19.100000
#
#        totalInletWater__ch1  totalOutletWater__ch1  moduleInletTemp__ch2  \
# count         338151.000000          338151.000000         338151.000000
# mean              16.202258              15.598329             15.935705
# std                1.209454               1.520875              1.211237
# min               13.100000              11.300000             12.900000
# 25%               15.300000              14.700000             15.000000
# 50%               16.200000              15.900000             15.900000
# 75%               17.200000              16.700000             16.900000
# max               19.400000              19.100000             19.200000
#
#        moduleOutletTemp__ch2  totalInletWater__ch2  totalOutletWater__ch2  \
# count          338151.000000         338151.000000          338151.000000
# mean               15.807541             15.935705              15.807541
# std                 1.812179              1.211237               1.812179
# min                 9.800000             12.900000               9.800000
# 25%                14.900000             15.000000              14.900000
# 50%                16.000000             15.900000              16.000000
# 75%                17.200000             16.900000              17.200000
# max                19.400000             19.200000              19.400000
#
#        supp_temp__ir1  ...  water_in_temp__ir1  water_out_temp__ir1  \
# count   338151.000000  ...       338151.000000        338151.000000
# mean        19.569290  ...           15.753236            15.832144
# std          0.310602  ...            1.133890             1.070200
# min         17.325000  ...           12.815000            13.255000
# 25%         19.360000  ...           14.905000            15.015000
# 50%         19.525000  ...           15.730000            15.785000
# 75%         19.855000  ...           16.665000            16.665000
# max         20.570000  ...           18.810000            18.700000
#
#        supp_temp__ir2  return_temp__ir2  fan_speed__ir2  unt_airflow__ir2  \
# count   338151.000000     338151.000000   338151.000000     338151.000000
# mean        19.807840         22.357740      229.852613         57.745407
# std          0.416161          0.527402       16.187048          3.872803
# min         16.225000         20.185000        0.000000          0.000000
# 25%         19.580000         21.890000      220.600000         56.000000
# 50%         19.910000         22.385000      230.100000         58.000000
# 75%         20.130000         22.825000      244.800000         61.000000
# max         21.670000         24.200000      254.100000         63.000000
#
#        water_flow__ir2  water_in_temp__ir2  water_out_temp__ir2          power
# count    338151.000000       338151.000000        338151.000000  338151.000000
# mean         10.506279           16.081691            20.316649     225.263443
# std           0.891289            1.105853             0.368469     313.947571
# min           0.000000           13.145000            16.775000     133.440000
# 25%          10.300000           15.290000            20.130000     203.760000
# 50%          10.500000           16.115000            20.350000     225.000000
# 75%          10.800000           16.940000            20.570000     245.300000
# max          12.400000           19.800000            22.440000   49017.960000
#
# [8 rows x 24 columns]

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df = df[df['power'] <= 10000]
df = df.reset_index(drop=True)

# %%
df['time'] = pd.to_datetime(df['time'])
df.set_index('time', inplace=True)

df = df[df.iloc[:, 23] <= 4000]
df = df.drop('Unnamed: 0', axis=1)

df_resampled = df.resample('1T').mean()
df_resampled = df_resampled.dropna()
# Out:
# <ipython-input-36-a75eadff0595>:7: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   df_resampled = df.resample('1T').mean()

# %% [markdown]
# # Prepare for Modelling

# %%
X = np.zeros((df_resampled.shape[0] - 1, 12))
y = np.zeros(df_resampled.shape[0] - 1)

for i in range (df_resampled.shape[0] - 1):
    if (df_resampled.index[i+1] == df_resampled.index[i] + pd.Timedelta(minutes=1)) :
        X[i,0] = df_resampled['moduleInletTemp__ch2'].iloc[i]
        X[i,1] = df_resampled['moduleOutletTemp__ch2'].iloc[i]
        X[i,2] = df_resampled['totalInletWater__ch2'].iloc[i]
        X[i,3] = df_resampled['totalOutletWater__ch2'].iloc[i]
        X[i,4] = df_resampled['supp_temp__ir2'].iloc[i]
        X[i,5] = df_resampled['return_temp__ir2'].iloc[i]
        X[i,6] = df_resampled['fan_speed__ir2'].iloc[i]
        X[i,7] = df_resampled['unt_airflow__ir2'].iloc[i]
        X[i,8] = df_resampled['water_flow__ir2'].iloc[i]
        X[i,9] = df_resampled['water_in_temp__ir2'].iloc[i]
        X[i,10] = df_resampled['water_out_temp__ir2'].iloc[i]
        X[i,11] = df_resampled['power'].iloc[i]

        y[i] = df_resampled['return_temp__ir2'].iloc[i + 1]


non_zero_indices = ~np.all(X == 0, axis=1)
X = X[non_zero_indices]
y = y[non_zero_indices]

# %%
len(X)
# Out:
# 56443

# %%
# split dataset into data train and data test

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=0)

# %%
# Build Model
model = Sequential([
    Dense(64, activation='relu', input_shape=(X.shape[1],), kernel_regularizer=l2(0.01)),
    Dense(1)
])

# Compile Model
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss = 'mse',
    metrics=[tf.keras.metrics.MeanSquaredError()]
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# model summary

model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                      │ (None, 64)                  │             832 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 897 (3.50 KB)
#  Trainable params: 897 (3.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# fit the model

history = model.fit(
    X_train, y_train,
    validation_split=0.1,
    epochs=50,  # Increased to allow for convergence
    batch_size=64,  # Adjusted for balance between stability and speed
    verbose=1
)
# Out:
# Epoch 1/50
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 1181.5265 - mean_squared_error: 1181.3839 - val_loss: 0.2970 - val_mean_squared_error: 0.1772
# Epoch 2/50
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2921 - mean_squared_error: 0.1730 - val_loss: 0.2463 - val_mean_squared_error: 0.1289
# Epoch 3/50
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2436 - mean_squared_error: 0.1269 - val_loss: 0.2523 - val_mean_squared_error: 0.1372
# Epoch 4/50
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.2171 - mean_squared_error: 0.1027 - val_loss: 0.1985 - val_mean_squared_error: 0.0861
# Epoch 5/50
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.1915 - mean_squared_error: 0.0796 - val_loss: 0.1638 - val_mean_squared_error: 0.0537
# Epoch 6/50
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.2060 - mean_squared_error: 0.0963 - val_loss: 0.1894 - val_mean_squared_error: 0.0808
# Epoch 7/50
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.1690 - mean_squared_error: 0.0611 - val_loss: 0.1506 - val_mean_squared_error: 0.0446
# Epoch 8/50
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1589 - mean_squared_error: 0.0535 - val_loss: 0.1356 - val_mean_squared_error: 0.0321
# Epoch 9/50
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1455 - mean_squared_error: 0.0426 - val_loss: 0.3194 - val_mean_squared_error: 0.2176
# Epoch 10/50
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.2398 - mean_squared_error: 0.1388 - val_loss: 0.1264 - val_mean_squared_error: 0.0274
# Epoch 11/50
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1343 - mean_squared_error: 0.0361 - val_loss: 0.1140 - val_mean_squared_error: 0.0181
# Epoch 12/50
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1248 - mean_squared_error: 0.0299 - val_loss: 0.1239 - val_mean_squared_error: 0.0317
# Epoch 13/50
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3348 - mean_squared_error: 0.2434 - val_loss: 0.1107 - val_mean_squared_error: 0.0217
# Epoch 14/50
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1134 - mean_squared_error: 0.0253 - val_loss: 0.1159 - val_mean_squared_error: 0.0306
# Epoch 15/50
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1119 - mean_squared_error: 0.0276 - val_loss: 0.1011 - val_mean_squared_error: 0.0197
# Epoch 16/50
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4419 - mean_squared_error: 0.3615 - val_loss: 0.0968 - val_mean_squared_error: 0.0184
# Epoch 17/50
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0893 - mean_squared_error: 0.0115 - val_loss: 0.0839 - val_mean_squared_error: 0.0084
# Epoch 18/50
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0900 - mean_squared_error: 0.0153 - val_loss: 0.0820 - val_mean_squared_error: 0.0099
# Epoch 19/50
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0955 - mean_squared_error: 0.0242 - val_loss: 0.0777 - val_mean_squared_error: 0.0091
# Epoch 20/50
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0915 - mean_squared_error: 0.0238 - val_loss: 0.1819 - val_mean_squared_error: 0.1166
# Epoch 21/50
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.3438 - mean_squared_error: 0.2790 - val_loss: 0.0726 - val_mean_squared_error: 0.0083
# Epoch 22/50
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0725 - mean_squared_error: 0.0088 - val_loss: 0.0713 - val_mean_squared_error: 0.0093
# Epoch 23/50
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0699 - mean_squared_error: 0.0085 - val_loss: 0.0806 - val_mean_squared_error: 0.0211
# Epoch 24/50
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0722 - mean_squared_error: 0.0132 - val_loss: 0.0659 - val_mean_squared_error: 0.0085
# Epoch 25/50
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1044 - mean_squared_error: 0.0477 - val_loss: 0.0608 - val_mean_squared_error: 0.0054
# Epoch 26/50
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0683 - mean_squared_error: 0.0135 - val_loss: 0.0631 - val_mean_squared_error: 0.0097
# Epoch 27/50
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1282 - mean_squared_error: 0.0752 - val_loss: 0.0587 - val_mean_squared_error: 0.0069
# Epoch 28/50
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0635 - mean_squared_error: 0.0121 - val_loss: 0.0743 - val_mean_squared_error: 0.0243
# Epoch 29/50
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.1240 - mean_squared_error: 0.0742 - val_loss: 0.0560 - val_mean_squared_error: 0.0071
# Epoch 30/50
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0862 - mean_squared_error: 0.0376 - val_loss: 0.0598 - val_mean_squared_error: 0.0120
# Epoch 31/50
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.1248 - mean_squared_error: 0.0773 - val_loss: 0.0515 - val_mean_squared_error: 0.0047
# Epoch 32/50
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0543 - mean_squared_error: 0.0079 - val_loss: 0.0530 - val_mean_squared_error: 0.0077
# Epoch 33/50
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0703 - mean_squared_error: 0.0253 - val_loss: 0.0603 - val_mean_squared_error: 0.0161
# Epoch 34/50
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1007 - mean_squared_error: 0.0568 - val_loss: 0.0490 - val_mean_squared_error: 0.0054
# Epoch 35/50
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0499 - mean_squared_error: 0.0067 - val_loss: 0.0533 - val_mean_squared_error: 0.0109
# Epoch 36/50
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0572 - mean_squared_error: 0.0152 - val_loss: 0.0494 - val_mean_squared_error: 0.0083
# Epoch 37/50
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0915 - mean_squared_error: 0.0505 - val_loss: 0.0445 - val_mean_squared_error: 0.0037
# Epoch 38/50
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0473 - mean_squared_error: 0.0068 - val_loss: 0.0442 - val_mean_squared_error: 0.0045
# Epoch 39/50
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0578 - mean_squared_error: 0.0184 - val_loss: 0.0540 - val_mean_squared_error: 0.0150
# Epoch 40/50
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0492 - mean_squared_error: 0.0105 - val_loss: 0.0440 - val_mean_squared_error: 0.0061
# Epoch 41/50
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0563 - mean_squared_error: 0.0187 - val_loss: 0.1002 - val_mean_squared_error: 0.0632
# Epoch 42/50
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0577 - mean_squared_error: 0.0210 - val_loss: 0.0414 - val_mean_squared_error: 0.0054
# Epoch 43/50
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0545 - mean_squared_error: 0.0188 - val_loss: 0.0385 - val_mean_squared_error: 0.0033
# Epoch 44/50
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0655 - mean_squared_error: 0.0304 - val_loss: 0.0433 - val_mean_squared_error: 0.0085
# Epoch 45/50
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0409 - mean_squared_error: 0.0063 - val_loss: 0.0447 - val_mean_squared_error: 0.0108
# Epoch 46/50
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0477 - mean_squared_error: 0.0140 - val_loss: 0.0581 - val_mean_squared_error: 0.0249
# Epoch 47/50
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0652 - mean_squared_error: 0.0320 - val_loss: 0.0366 - val_mean_squared_error: 0.0037
# Epoch 48/50
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0400 - mean_squared_error: 0.0073 - val_loss: 0.0596 - val_mean_squared_error: 0.0275
# Epoch 49/50
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0529 - mean_squared_error: 0.0210 - val_loss: 0.0418 - val_mean_squared_error: 0.0102
# Epoch 50/50
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0458 - mean_squared_error: 0.0145 - val_loss: 0.0575 - val_mean_squared_error: 0.0266

# %%
# plot training loss and validation loss

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# %% [markdown]
# # Compare y_true and y_pred

# %%
print(len(X))
print(len(y))
# Out:
# 56443
# 56443

# %%
y_test_pred = model.predict(X_test)

plt.plot([x for x in range(len(y_test))], y_test, label='Actual')
plt.plot([x for x in range(len(y_test))], y_test_pred, label='Predicted')

plt.xlabel('Date')
plt.ylabel('Temperature')
plt.title('Actual vs. Predicted Temperature Over Time')
plt.legend()
plt.show()

# %%
joblib.dump(model, '/content/drive/My Drive/Project 2 (TPT)/model_inrow2.pkl')
# Out:
# ['/content/drive/My Drive/Project 2 (TPT)/model_inrow2.pkl']

# %%
model.save('model_inrow2.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
